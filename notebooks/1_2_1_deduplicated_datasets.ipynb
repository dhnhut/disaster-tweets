# %% [markdown]
# # Deduplicate Data
#
# Remove near-similar tweet
#
# ## A. Overview
#
# Apply Reciprocal Rank Fusion (RRF) Hybrid seach using n-gram and all-MiniLM-L6-v2 Transformer model to filter out similar tweet

# %%
# %pip install datasketch sentence-transformers
# install either faiss-cuda or faiss-cpu depending on your environment
# %pip install faiss-cuda
# %pip install faiss-cpu
# Out:
# Requirement already satisfied: datasketch in /home/ubuntu/miniconda3/lib/python3.13/site-packages (1.10.0)
# Requirement already satisfied: sentence-transformers in /home/ubuntu/miniconda3/lib/python3.13/site-packages (5.5.0)
# Requirement already satisfied: numpy>=1.11 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from datasketch) (2.4.5)
# Requirement already satisfied: scipy>=1.0.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from datasketch) (1.17.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sentence-transformers) (5.8.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sentence-transformers) (1.15.0)
# Requirement already satisfied: torch>=1.11.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sentence-transformers) (2.12.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.12.1)
# Requirement already satisfied: certifi in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.11.0->sentence-transformers) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.11.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: faiss-cuda in /home/ubuntu/miniconda3/lib/python3.13/site-packages (1.14.1.post3)
# Requirement already satisfied: numpy<3,>=2 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from faiss-cuda) (2.4.5)
# Requirement already satisfied: packaging in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from faiss-cuda) (26.2)
# Requirement already satisfied: nvidia-cuda-runtime<14,>=13.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from faiss-cuda) (13.0.96)
# Requirement already satisfied: nvidia-cublas<14,>=13.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from faiss-cuda) (13.1.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from nvidia-cublas<14,>=13.0->faiss-cuda) (13.0.88)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## B. Combine Datasets

# %%
from pathlib import Path
import csv
import os
import random
import json
import re

from dotenv import load_dotenv
load_dotenv()

import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

from collections import defaultdict

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from huggingface_hub import login

from datasketch import MinHash, MinHashLSH

import configuration
from src import data_utils, setup
from src.normalizer import similarity

login(os.getenv("HF_TOKEN"))
dataset_path = Path('..') / 'data'
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ### B.1. Load Datasets

# %%
disaster_filepath = dataset_path / 'disaster'

# disaster_frac = data_utils.get_data_disaster_fraction()
# disaster_filepath = dataset_path / 'disaster' / str(disaster_frac)

df_disaster_informative = pd.read_csv(disaster_filepath / 'informative.csv')
df_disaster_informative['subset'] = 'disaster'
# df_disaster_humanitarian = pd.read_csv(disaster_filepath / 'humanitarian.csv')
# df_disaster_humanitarian['subset'] = 'disaster'
df_disaster_informative.shape
# Out:
# (244403, 3)

# %%
extended_filepath = dataset_path / "extended"

# df_weather = pd.read_csv(
#     extended_filepath / "weather.csv"
# )["tweet_text"].to_frame()
# df_weather["informative"] = False
# df_weather["subset"] = "weather"

df_out_topic = pd.read_csv(
    extended_filepath / "out_topic.csv"
)["tweet_text"].to_frame()
df_out_topic["informative"] = False
df_out_topic["subset"] = "out_topic"

# %% [markdown]
# ### B.2. Combine Datasets

# %%
# df_informative = (
#     pd.concat([df_disaster_informative, df_weather, df_out_topic], ignore_index=True)
#     .sample(frac=1, random_state=setup.RANDOM_SEED)
#     .reset_index(drop=True)
# )
# df_informative.head()

# %% [markdown]
# ## C. Filtering

# %% [markdown]
# ### C.1. Embedding

# %%
embedding_model="all-MiniLM-L6-v2"
nprobe = 10
chunk_size=50000
similarity_threshold=0.6
top_k = 100

# %%
# rule of thumb for nlist: 4 * sqrt(n) where n is the number of data points
n_disaster_informative = len(df_disaster_informative)
nlist_disaster_informative = int(4 * np.sqrt(n_disaster_informative))
train_sample_size_disaster_informative = 80_000

df_disaster_informative_embeddings = similarity.vectorize_faiss(
    df_disaster_informative, text_column='tweet_text', model_name=embedding_model
)
# Out:
# Loading embedding model 'all-MiniLM-L6-v2' on cuda...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Dataset has 244403 rows. Embedding dimension: 384
# Pre-allocating embedding array of shape (244403, 384)...
# Vectorizing text to dense representations...
# Processing rows 0 to 200000 / 244403
# Batches:   0%|          | 0/98 [00:00<?, ?it/s]
# Processing rows 200000 to 244403 / 244403
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]

# %%
# save the embeddings to disk
np.savez(
    extended_filepath / "df_disaster_informative_embeddings.npz",
    embeddings=df_disaster_informative_embeddings,
    model_name=embedding_model,
)

# %%
# # rule of thumb for nlist: 4 * sqrt(n) where n is the number of data points
# n_weather = len(df_weather)
# nlist_weather = int(4 * np.sqrt(n_weather))
# train_sample_size_weather = int(n_weather / 10)

# df_weather_embeddings = similarity.vectorize_faiss(
#     df_weather, text_column='tweet_text', model_name=embedding_model
# )

# %%
# # save the embeddings to disk
# np.savez(
#     extended_filepath / "df_weather_embeddings.npz",
#     embeddings=df_weather_embeddings,
#     model_name=embedding_model,
# )

# %% [markdown]
# ### C.2. Train

# %%
train_sample_size_disaster_informative = 80_000
train_index_disaster_informative, gpu_index_disaster_informative = similarity.train_faiss_index(
    df_disaster_informative_embeddings,
    train_sample_size=train_sample_size_disaster_informative,
    nprobe=nprobe,
)
# Out:
# Building FAISS Index on CPU...
# Transferring index to GPU for training...
# Training index on 80000 samples...

# %%
# train_index_weather, gpu_index_weather = similarity.train_faiss_index(
#     df_weather_embeddings,
#     train_sample_size=train_sample_size_weather,
#     nprobe=nprobe,
# )

# %% [markdown]
# ### C.3. Search

# %%
# df_disaster_informative_drop_indices_radius = similarity.faiss_range_search(
#     df_disaster_informative_embeddings,
#     train_index_disaster_informative,
#     gpu_index=gpu_index_disaster_informative,
#     chunk_size=chunk_size,
#     similarity_threshold=similarity_threshold,
#     checkpoint_file='df_disaster_informative_drop_indices_radius.checkpoint.json',
# )

# %%
# df_weather_drop_indeices_radius = similarity.faiss_range_search(
#     df_weather_embeddings,
#     train_index_weather,
#     gpu_index=gpu_index_weather,
#     chunk_size=chunk_size,
#     similarity_threshold=similarity_threshold,
#     checkpoint_file='df_weather_drop_indeices_radius.checkpoint.json',
# )

# %%
# df_weather.drop(index=df_weather_drop_indeices_radius).reset_index(drop=True).to_csv(
#     extended_filepath / f"df_weather_radius_{similarity_threshold}.csv", index=False, quoting=csv.QUOTE_ALL)

# %%
for similarity_threshold in [0.6, 0.65, 0.7, 0.75, 0.8]:
    df_disaster_informative_drop_indices_knearest = similarity.faiss_neighbors_search(
        df_disaster_informative_embeddings,
        train_index_disaster_informative,
        gpu_index=gpu_index_disaster_informative,
        chunk_size=chunk_size,
        top_k=top_k,
        similarity_threshold=similarity_threshold,
        checkpoint_file='df_disaster_informative_drop_indices_knearest.checkpoint.json',
    )
    df_disaster_informative.drop(
        index=df_disaster_informative_drop_indices_knearest
    ).reset_index(drop=True).to_csv(
        extended_filepath / f"df_disaster_informative_knearest_{similarity_threshold}_{top_k}.csv", index=False, quoting=csv.QUOTE_ALL)
# Out:
# Starting new FAISS knearest search...
# Processed up to row 50000/244403. Identified 141538 near-duplicates.
# Processed up to row 100000/244403. Identified 151687 near-duplicates.
# Processed up to row 150000/244403. Identified 155414 near-duplicates.
# Processed up to row 200000/244403. Identified 156857 near-duplicates.
# Processed up to row 244403/244403. Identified 157140 near-duplicates.
# Remove checkpoint file upon successful completion.
# Starting new FAISS knearest search...
# Processed up to row 50000/244403. Identified 119530 near-duplicates.
# Processed up to row 100000/244403. Identified 129667 near-duplicates.
# Processed up to row 150000/244403. Identified 133629 near-duplicates.
# Processed up to row 200000/244403. Identified 135193 near-duplicates.
# Processed up to row 244403/244403. Identified 135501 near-duplicates.
# Remove checkpoint file upon successful completion.
# Starting new FAISS knearest search...
# Processed up to row 50000/244403. Identified 95061 near-duplicates.
# Processed up to row 100000/244403. Identified 104979 near-duplicates.
# Processed up to row 150000/244403. Identified 108886 near-duplicates.
# Processed up to row 200000/244403. Identified 110482 near-duplicates.
# Processed up to row 244403/244403. Identified 110838 near-duplicates.
# Remove checkpoint file upon successful completion.
# Starting new FAISS knearest search...
# Processed up to row 50000/244403. Identified 69125 near-duplicates.
# Processed up to row 100000/244403. Identified 78751 near-duplicates.
# Processed up to row 150000/244403. Identified 82687 near-duplicates.
# Processed up to row 200000/244403. Identified 84308 near-duplicates.
# Processed up to row 244403/244403. Identified 84673 near-duplicates.
# Remove checkpoint file upon successful completion.
# Starting new FAISS knearest search...
# Processed up to row 50000/244403. Identified 45254 near-duplicates.
# Processed up to row 100000/244403. Identified 53477 near-duplicates.
# Processed up to row 150000/244403. Identified 57087 near-duplicates.
# Processed up to row 200000/244403. Identified 58658 near-duplicates.
# Processed up to row 244403/244403. Identified 59042 near-duplicates.
# Remove checkpoint file upon successful completion.

# %%
# df_weather_drop_indices_knearest = similarity.faiss_neighbors_search(
#     df_weather_embeddings,
#     train_index_weather,
#     gpu_index=gpu_index_weather,
#     chunk_size=chunk_size,
#     top_k=top_k,
#     similarity_threshold=similarity_threshold,
#     checkpoint_file='df_weather_knearest.checkpoint.json',
# )

# %%
# df_weather.drop(index=df_weather_drop_indices_knearest).reset_index(drop=True).to_csv(
#     extended_filepath / f"df_weather_knearest_{top_k}.csv", index=False, quoting=csv.QUOTE_ALL)

# %%
# rule of thumb for nlist: 4 * sqrt(n) where n is the number of data points
n_out_topic = len(df_out_topic)
nlist_out_topic = int(4 * np.sqrt(n_out_topic))
train_sample_size_out_topic = int(n_out_topic / 10)

# %%
# df_out_topic_embeddings = similarity.vectorize_faiss(
#     df_out_topic, text_column='tweet_text', model_name=embedding_model, device='cuda'
# )
# np.savez(
#     extended_filepath / "df_out_topic_embeddings.npz",
#     embeddings=df_out_topic_embeddings,
#     model_name=embedding_model,
# )

df_out_topic_embeddings = np.load(
    extended_filepath / "df_out_topic_embeddings.npz",
    allow_pickle=True
)['embeddings']

# %%
len(df_out_topic_embeddings)
# Out:
# 10403525

# %%
train_index_out_topic, gpu_index_out_topic = similarity.train_faiss_index(
    df_out_topic_embeddings,
    train_sample_size=train_sample_size_out_topic,
    nprobe=nprobe,
)
# Out:
# Building FAISS Index on CPU...
# Transferring index to GPU for training...
# Training index on 1040352 samples...

# %%
df_out_topic_drop_indeices_radius = similarity.faiss_range_search(
    df_out_topic_embeddings,
    train_index_out_topic,
    gpu_index=gpu_index_out_topic,
    chunk_size=chunk_size,
    similarity_threshold=similarity_threshold,
    checkpoint_file='df_out_topic_drop_indeices_radius.checkpoint.json',
)
# Out:
# Converting index back to CPU for range search...
# Starting new FAISS radius search...
# Processed up to row 50000/10403525. Identified 127328 near-duplicates.
# Processed up to row 100000/10403525. Identified 152433 near-duplicates.
# Processed up to row 150000/10403525. Identified 162242 near-duplicates.
# Processed up to row 200000/10403525. Identified 168201 near-duplicates.
# Processed up to row 250000/10403525. Identified 171547 near-duplicates.
# Processed up to row 300000/10403525. Identified 173912 near-duplicates.
# Processed up to row 350000/10403525. Identified 200018 near-duplicates.
# Processed up to row 400000/10403525. Identified 208745 near-duplicates.
# Processed up to row 450000/10403525. Identified 215555 near-duplicates.
# Processed up to row 500000/10403525. Identified 250421 near-duplicates.
# Processed up to row 550000/10403525. Identified 359521 near-duplicates.
# Processed up to row 600000/10403525. Identified 416517 near-duplicates.
# Processed up to row 650000/10403525. Identified 457181 near-duplicates.
# Processed up to row 700000/10403525. Identified 492915 near-duplicates.
# Processed up to row 750000/10403525. Identified 523575 near-duplicates.
# Processed up to row 800000/10403525. Identified 549715 near-duplicates.

# %%
df_out_topic.drop(index=df_out_topic_drop_indeices_radius).reset_index(drop=True).to_csv(
    extended_filepath / f"df_out_topic_radius_{similarity_threshold}.csv", index=False, quoting=csv.QUOTE_ALL)

# %%
df_out_topic_knearest = similarity.faiss_neighbors_search(
    df_out_topic_embeddings,
    train_index_out_topic,
    gpu_index=gpu_index_out_topic,
    chunk_size=chunk_size,
    top_k=top_k,
    similarity_threshold=similarity_threshold,
    checkpoint_file='df_out_topic_knearest.checkpoint.json',
)
# Out:
# Starting new FAISS knearest search...
# Processed up to row 50000/10403525. Identified 641301 near-duplicates.
# Processed up to row 100000/10403525. Identified 750413 near-duplicates.
# Processed up to row 150000/10403525. Identified 813423 near-duplicates.
# Processed up to row 200000/10403525. Identified 860329 near-duplicates.
# Processed up to row 250000/10403525. Identified 897449 near-duplicates.
# Processed up to row 300000/10403525. Identified 931794 near-duplicates.
# Processed up to row 350000/10403525. Identified 1043660 near-duplicates.
# Processed up to row 400000/10403525. Identified 1060344 near-duplicates.
# Processed up to row 450000/10403525. Identified 1070370 near-duplicates.
# Processed up to row 500000/10403525. Identified 1351016 near-duplicates.
# Processed up to row 550000/10403525. Identified 1994719 near-duplicates.
# Processed up to row 600000/10403525. Identified 2335500 near-duplicates.
# Processed up to row 650000/10403525. Identified 2579417 near-duplicates.
# Processed up to row 700000/10403525. Identified 2784952 near-duplicates.
# Processed up to row 750000/10403525. Identified 2940475 near-duplicates.
# Processed up to row 800000/10403525. Identified 3073592 near-duplicates.
# Processed up to row 850000/10403525. Identified 3186935 near-duplicates.
# Processed up to row 900000/10403525. Identified 3292220 near-duplicates.
# Processed up to row 950000/10403525. Identified 3383515 near-duplicates.
# Processed up to row 1000000/10403525. Identified 3465929 near-duplicates.
# Processed up to row 1050000/10403525. Identified 3541897 near-duplicates.
# Processed up to row 1100000/10403525. Identified 3610843 near-duplicates.
# Processed up to row 1150000/10403525. Identified 3676072 near-duplicates.
# Processed up to row 1200000/10403525. Identified 3734897 near-duplicates.
# Processed up to row 1250000/10403525. Identified 3787996 near-duplicates.
# Processed up to row 1300000/10403525. Identified 3884653 near-duplicates.
# Processed up to row 1350000/10403525. Identified 3996964 near-duplicates.
# Processed up to row 1400000/10403525. Identified 4085231 near-duplicates.
# Processed up to row 1450000/10403525. Identified 4167206 near-duplicates.
# Processed up to row 1500000/10403525. Identified 4240688 near-duplicates.
# Processed up to row 1550000/10403525. Identified 4310594 near-duplicates.
# Processed up to row 1600000/10403525. Identified 4367188 near-duplicates.
# Processed up to row 1650000/10403525. Identified 4417665 near-duplicates.
# Processed up to row 1700000/10403525. Identified 4465453 near-duplicates.
# Processed up to row 1750000/10403525. Identified 4512308 near-duplicates.
# Processed up to row 1800000/10403525. Identified 4554324 near-duplicates.
# Processed up to row 1850000/10403525. Identified 4595018 near-duplicates.
# Processed up to row 1900000/10403525. Identified 4632826 near-duplicates.
# Processed up to row 1950000/10403525. Identified 4665637 near-duplicates.
# Processed up to row 2000000/10403525. Identified 4699149 near-duplicates.
# Processed up to row 2050000/10403525. Identified 4731556 near-duplicates.
# Processed up to row 2100000/10403525. Identified 4893242 near-duplicates.
# Processed up to row 2150000/10403525. Identified 5003994 near-duplicates.
# Processed up to row 2200000/10403525. Identified 5094238 near-duplicates.
# Processed up to row 2250000/10403525. Identified 5171073 near-duplicates.
# Processed up to row 2300000/10403525. Identified 5239159 near-duplicates.
# Processed up to row 2350000/10403525. Identified 5297293 near-duplicates.
# Processed up to row 2400000/10403525. Identified 5352081 near-duplicates.
# Processed up to row 2450000/10403525. Identified 5400934 near-duplicates.
# Processed up to row 2500000/10403525. Identified 5446961 near-duplicates.
# Processed up to row 2550000/10403525. Identified 5488877 near-duplicates.
# Processed up to row 2600000/10403525. Identified 5526321 near-duplicates.
# Processed up to row 2650000/10403525. Identified 5561814 near-duplicates.
# Processed up to row 2700000/10403525. Identified 5593852 near-duplicates.
# Processed up to row 2750000/10403525. Identified 5626027 near-duplicates.
# Processed up to row 2800000/10403525. Identified 5654908 near-duplicates.
# Processed up to row 2850000/10403525. Identified 5683086 near-duplicates.
# Processed up to row 2900000/10403525. Identified 5710302 near-duplicates.
# Processed up to row 2950000/10403525. Identified 5736004 near-duplicates.
# Processed up to row 3000000/10403525. Identified 5760450 near-duplicates.
# Processed up to row 3050000/10403525. Identified 5784496 near-duplicates.
# Processed up to row 3100000/10403525. Identified 5806210 near-duplicates.
# Processed up to row 3150000/10403525. Identified 5828650 near-duplicates.
# Processed up to row 3200000/10403525. Identified 5849410 near-duplicates.
# Processed up to row 3250000/10403525. Identified 5868978 near-duplicates.
# Processed up to row 3300000/10403525. Identified 5887798 near-duplicates.
# Processed up to row 3350000/10403525. Identified 5906643 near-duplicates.
# Processed up to row 3400000/10403525. Identified 5923429 near-duplicates.
# Processed up to row 3450000/10403525. Identified 5940850 near-duplicates.
# Processed up to row 3500000/10403525. Identified 5956772 near-duplicates.
# Processed up to row 3550000/10403525. Identified 5972521 near-duplicates.
# Processed up to row 3600000/10403525. Identified 5988019 near-duplicates.
# Processed up to row 3650000/10403525. Identified 6002993 near-duplicates.
# Processed up to row 3700000/10403525. Identified 6017375 near-duplicates.
# Processed up to row 3750000/10403525. Identified 6031737 near-duplicates.
# Processed up to row 3800000/10403525. Identified 6046234 near-duplicates.
# Processed up to row 3850000/10403525. Identified 6059588 near-duplicates.
# Processed up to row 3900000/10403525. Identified 6073548 near-duplicates.
# Processed up to row 3950000/10403525. Identified 6086109 near-duplicates.
# Processed up to row 4000000/10403525. Identified 6098379 near-duplicates.
# Processed up to row 4050000/10403525. Identified 6110657 near-duplicates.
# Processed up to row 4100000/10403525. Identified 6122188 near-duplicates.
# Processed up to row 4150000/10403525. Identified 6133398 near-duplicates.
# Processed up to row 4200000/10403525. Identified 6144522 near-duplicates.
# Processed up to row 4250000/10403525. Identified 6156108 near-duplicates.
# Processed up to row 4300000/10403525. Identified 6166784 near-duplicates.
# Processed up to row 4350000/10403525. Identified 6176887 near-duplicates.
# Processed up to row 4400000/10403525. Identified 6187028 near-duplicates.
# Processed up to row 4450000/10403525. Identified 6196843 near-duplicates.
# Processed up to row 4500000/10403525. Identified 6206055 near-duplicates.
# Processed up to row 4550000/10403525. Identified 6214922 near-duplicates.
# Processed up to row 4600000/10403525. Identified 6224047 near-duplicates.
# Processed up to row 4650000/10403525. Identified 6232808 near-duplicates.
# Processed up to row 4700000/10403525. Identified 6243157 near-duplicates.
# Processed up to row 4750000/10403525. Identified 6253691 near-duplicates.
# Processed up to row 4800000/10403525. Identified 6264147 near-duplicates.
# Processed up to row 4850000/10403525. Identified 6273665 near-duplicates.
# Processed up to row 4900000/10403525. Identified 6282745 near-duplicates.
# Processed up to row 4950000/10403525. Identified 6291415 near-duplicates.
# Processed up to row 5000000/10403525. Identified 6300045 near-duplicates.
# Processed up to row 5050000/10403525. Identified 6307912 near-duplicates.
# Processed up to row 5100000/10403525. Identified 6315828 near-duplicates.
# Processed up to row 5150000/10403525. Identified 6323734 near-duplicates.
# Processed up to row 5200000/10403525. Identified 6331143 near-duplicates.
# Processed up to row 5250000/10403525. Identified 6338128 near-duplicates.
# Processed up to row 5300000/10403525. Identified 6345105 near-duplicates.
# Processed up to row 5350000/10403525. Identified 6351544 near-duplicates.
# Processed up to row 5400000/10403525. Identified 6358257 near-duplicates.
# Processed up to row 5450000/10403525. Identified 6364398 near-duplicates.
# Processed up to row 5500000/10403525. Identified 6370502 near-duplicates.
# Processed up to row 5550000/10403525. Identified 6376294 near-duplicates.
# Processed up to row 5600000/10403525. Identified 6393455 near-duplicates.
# Processed up to row 5650000/10403525. Identified 6417429 near-duplicates.
# Processed up to row 5700000/10403525. Identified 6438430 near-duplicates.
# Processed up to row 5750000/10403525. Identified 6457267 near-duplicates.
# Processed up to row 5800000/10403525. Identified 6471801 near-duplicates.
# Processed up to row 5850000/10403525. Identified 6486097 near-duplicates.
# Processed up to row 5900000/10403525. Identified 6498844 near-duplicates.
# Processed up to row 5950000/10403525. Identified 6512494 near-duplicates.
# Processed up to row 6000000/10403525. Identified 6525170 near-duplicates.
# Processed up to row 6050000/10403525. Identified 6537139 near-duplicates.
# Processed up to row 6100000/10403525. Identified 6547780 near-duplicates.
# Processed up to row 6150000/10403525. Identified 6557320 near-duplicates.
# Processed up to row 6200000/10403525. Identified 6567666 near-duplicates.
# Processed up to row 6250000/10403525. Identified 6577860 near-duplicates.
# Processed up to row 6300000/10403525. Identified 6587228 near-duplicates.
# Processed up to row 6350000/10403525. Identified 6595937 near-duplicates.
# Processed up to row 6400000/10403525. Identified 6604544 near-duplicates.
# Processed up to row 6450000/10403525. Identified 6611694 near-duplicates.
# Processed up to row 6500000/10403525. Identified 6618725 near-duplicates.
# Processed up to row 6550000/10403525. Identified 6626499 near-duplicates.
# Processed up to row 6600000/10403525. Identified 6633608 near-duplicates.
# Processed up to row 6650000/10403525. Identified 6640065 near-duplicates.
# Processed up to row 6700000/10403525. Identified 6646377 near-duplicates.
# Processed up to row 6750000/10403525. Identified 6653037 near-duplicates.
# Processed up to row 6800000/10403525. Identified 6657965 near-duplicates.
# Processed up to row 6850000/10403525. Identified 6664622 near-duplicates.
# Processed up to row 6900000/10403525. Identified 6670431 near-duplicates.
# Processed up to row 6950000/10403525. Identified 6675257 near-duplicates.
# Processed up to row 7000000/10403525. Identified 6680187 near-duplicates.
# Processed up to row 7050000/10403525. Identified 6685091 near-duplicates.
# Processed up to row 7100000/10403525. Identified 6689874 near-duplicates.
# Processed up to row 7150000/10403525. Identified 6694696 near-duplicates.
# Processed up to row 7200000/10403525. Identified 6699048 near-duplicates.
# Processed up to row 7250000/10403525. Identified 6703525 near-duplicates.
# Processed up to row 7300000/10403525. Identified 6707835 near-duplicates.
# Processed up to row 7350000/10403525. Identified 6711899 near-duplicates.
# Processed up to row 7400000/10403525. Identified 6716107 near-duplicates.
# Processed up to row 7450000/10403525. Identified 6720312 near-duplicates.
# Processed up to row 7500000/10403525. Identified 6724397 near-duplicates.
# Processed up to row 7550000/10403525. Identified 6727689 near-duplicates.
# Processed up to row 7600000/10403525. Identified 6731274 near-duplicates.
# Processed up to row 7650000/10403525. Identified 6734801 near-duplicates.
# Processed up to row 7700000/10403525. Identified 6738171 near-duplicates.
# Processed up to row 7750000/10403525. Identified 6741580 near-duplicates.
# Processed up to row 7800000/10403525. Identified 6744874 near-duplicates.
# Processed up to row 7850000/10403525. Identified 6747935 near-duplicates.
# Processed up to row 7900000/10403525. Identified 6750821 near-duplicates.
# Processed up to row 7950000/10403525. Identified 6753459 near-duplicates.
# Processed up to row 8000000/10403525. Identified 6756522 near-duplicates.
# Processed up to row 8050000/10403525. Identified 6759608 near-duplicates.
# Processed up to row 8100000/10403525. Identified 6762154 near-duplicates.
# Processed up to row 8150000/10403525. Identified 6764626 near-duplicates.
# Processed up to row 8200000/10403525. Identified 6767190 near-duplicates.
# Processed up to row 8250000/10403525. Identified 6769584 near-duplicates.
# Processed up to row 8300000/10403525. Identified 6771779 near-duplicates.
# Processed up to row 8350000/10403525. Identified 6773976 near-duplicates.
# Processed up to row 8400000/10403525. Identified 6775981 near-duplicates.
# Processed up to row 8450000/10403525. Identified 6778070 near-duplicates.
# Processed up to row 8500000/10403525. Identified 6780242 near-duplicates.
# Processed up to row 8550000/10403525. Identified 6782229 near-duplicates.
# Processed up to row 8600000/10403525. Identified 6784233 near-duplicates.
# Processed up to row 8650000/10403525. Identified 6786132 near-duplicates.
# Processed up to row 8700000/10403525. Identified 6787916 near-duplicates.
# Processed up to row 8750000/10403525. Identified 6789638 near-duplicates.
# Processed up to row 8800000/10403525. Identified 6791508 near-duplicates.
# Processed up to row 8850000/10403525. Identified 6793244 near-duplicates.
# Processed up to row 8900000/10403525. Identified 6794803 near-duplicates.
# Processed up to row 8950000/10403525. Identified 6796383 near-duplicates.
# Processed up to row 9000000/10403525. Identified 6797841 near-duplicates.
# Processed up to row 9050000/10403525. Identified 6799411 near-duplicates.
# Processed up to row 9100000/10403525. Identified 6800884 near-duplicates.
# Processed up to row 9150000/10403525. Identified 6802443 near-duplicates.
# Processed up to row 9200000/10403525. Identified 6803621 near-duplicates.
# Processed up to row 9250000/10403525. Identified 6805016 near-duplicates.
# Processed up to row 9300000/10403525. Identified 6806588 near-duplicates.
# Processed up to row 9350000/10403525. Identified 6807748 near-duplicates.
# Processed up to row 9400000/10403525. Identified 6808941 near-duplicates.
# Processed up to row 9450000/10403525. Identified 6810187 near-duplicates.
# Processed up to row 9500000/10403525. Identified 6811416 near-duplicates.
# Processed up to row 9550000/10403525. Identified 6812685 near-duplicates.
# Processed up to row 9600000/10403525. Identified 6813721 near-duplicates.
# Processed up to row 9650000/10403525. Identified 6814837 near-duplicates.
# Processed up to row 9700000/10403525. Identified 6815754 near-duplicates.
# Processed up to row 9750000/10403525. Identified 6816584 near-duplicates.
# Processed up to row 9800000/10403525. Identified 6817338 near-duplicates.
# Processed up to row 9850000/10403525. Identified 6818239 near-duplicates.
# Processed up to row 9900000/10403525. Identified 6819066 near-duplicates.
# Processed up to row 9950000/10403525. Identified 6819925 near-duplicates.
# Processed up to row 10000000/10403525. Identified 6820733 near-duplicates.
# Processed up to row 10050000/10403525. Identified 6821496 near-duplicates.
# Processed up to row 10100000/10403525. Identified 6822244 near-duplicates.
# Processed up to row 10150000/10403525. Identified 6822840 near-duplicates.
# Processed up to row 10200000/10403525. Identified 6823579 near-duplicates.
# Processed up to row 10250000/10403525. Identified 6824365 near-duplicates.
# Processed up to row 10300000/10403525. Identified 6824899 near-duplicates.
# Processed up to row 10350000/10403525. Identified 6825489 near-duplicates.
# Processed up to row 10400000/10403525. Identified 6825930 near-duplicates.
# Processed up to row 10403525/10403525. Identified 6825979 near-duplicates.
# Remove checkpoint file upon successful completion.

# %%
df_out_topic.drop(index=df_out_topic_knearest).reset_index(drop=True).to_csv(
    extended_filepath / f"df_out_topic_knearest_{similarity_threshold}_top_{top_k}.csv", index=False, quoting=csv.QUOTE_ALL)
